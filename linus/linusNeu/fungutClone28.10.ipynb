# %% [markdown]
# # Fungut

# %% [markdown]
# # 00 Packages and Directory

# %%
# %matplotlib inline

import os
import IPython
import pandas as pd
import matplotlib.pyplot as plt

import qiime2 as q2
from qiime2 import Visualization

data_dir = 'data'
PATH = "data/fungut_metadata.tsv"
surveys_df = pd.read_csv(PATH, sep="\t")

# %% [markdown]
# # 01 Data import

# %%
! qiime tools peek $data_dir/fungut_forward_reads.qza
# Out:
# UUID:        3638611d-1767-413b-9390-70ee3d78e4ff
# Type:        SampleData[SequencesWithQuality]
# Data format: SingleLanePerSampleSingleEndFastqDirFmt

# %%
! qiime demux summarize \
  --i-data $data_dir/fungut_forward_reads.qza \
  --o-visualization $data_dir/01/demux_summary.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: data/01/demux_summary.qzv

# %%
Visualization.load(f"{data_dir}/01/demux_summary.qzv")
# Out:
# <visualization: Visualization uuid: 790dee0d-05d2-4a74-a44a-467a2b8d2fec>

# %% [markdown]
# # 02 Trimming the primers

# %%
! qiime cutadapt trim-single \
  --i-demultiplexed-sequences $data_dir/fungut_forward_reads.qza \
  --p-front CTTGGTCATTTAGAGGAAGTAA \
  --o-trimmed-sequences $data_dir/02/fungut_forward_reads_trimmed.qza \
  --verbose
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327198_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327198_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327198_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327198_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        35,631 reads @   4.7 µs/read;  12.75 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  35,631
# Reads with adapters:                        56 (0.2%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        35,631 (100.0%)
#
# Total basepairs processed:     5,350,207 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      5,350,000 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 56 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	18	556.7	0	18
# 4	37	139.2	0	37
# 5	1	34.8	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327199_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327199_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327199_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327199_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        69,532 reads @   4.3 µs/read;  14.11 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  69,532
# Reads with adapters:                        69 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        69,532 (100.0%)
#
# Total basepairs processed:    10,431,308 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     10,431,040 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 69 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	16	1086.4	0	16
# 4	48	271.6	0	48
# 5	2	67.9	0	2
# 6	3	17.0	0	3
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327266_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327266_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327266_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327266_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        55,560 reads @   4.4 µs/read;  13.61 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  55,560
# Reads with adapters:                        54 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        55,560 (100.0%)
#
# Total basepairs processed:     8,387,886 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      8,387,677 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 54 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	11	868.1	0	11
# 4	41	217.0	0	41
# 6	2	13.6	0	2
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327282_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327282_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327282_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327282_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        77,651 reads @   4.4 µs/read;  13.57 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  77,651
# Reads with adapters:                        64 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        77,651 (100.0%)
#
# Total basepairs processed:    11,682,432 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,682,192 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 64 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	17	1213.3	0	17
# 4	46	303.3	0	46
# 5	1	75.8	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327284_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327284_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327284_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327284_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        20,567 reads @   4.9 µs/read;  12.27 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  20,567
# Reads with adapters:                        21 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        20,567 (100.0%)
#
# Total basepairs processed:     3,103,965 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      3,103,888 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 21 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	7	321.4	0	7
# 4	14	80.3	0	14
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327285_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327285_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327285_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327285_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        72,983 reads @   4.9 µs/read;  12.19 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  72,983
# Reads with adapters:                        92 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        72,983 (100.0%)
#
# Total basepairs processed:    11,016,656 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,016,307 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 92 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	21	1140.4	0	21
# 4	70	285.1	0	70
# 6	1	17.8	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327287_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327287_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327287_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327287_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        51,395 reads @   4.4 µs/read;  13.70 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  51,395
# Reads with adapters:                        49 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        51,395 (100.0%)
#
# Total basepairs processed:     7,758,649 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      7,758,463 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 49 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	10	803.0	0	10
# 4	39	200.8	0	39
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327288_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327288_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327288_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327288_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        79,528 reads @   4.3 µs/read;  13.83 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  79,528
# Reads with adapters:                        64 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        79,528 (100.0%)
#
# Total basepairs processed:    11,930,662 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,930,421 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 64 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	17	1242.6	0	17
# 4	45	310.7	0	45
# 5	2	77.7	0	2
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327289_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327289_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327289_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327289_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        81,068 reads @   4.4 µs/read;  13.63 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  81,068
# Reads with adapters:                        79 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        81,068 (100.0%)
#
# Total basepairs processed:    12,239,266 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     12,238,954 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 79 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	13	1266.7	0	13
# 4	64	316.7	0	64
# 5	1	79.2	0	1
# 12	1	0.0	1	0 1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327300_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327300_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327300_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327300_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        60,148 reads @   4.7 µs/read;  12.73 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  60,148
# Reads with adapters:                        62 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        60,148 (100.0%)
#
# Total basepairs processed:     9,078,963 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      9,078,734 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 62 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	19	939.8	0	19
# 4	43	235.0	0	43
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327303_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327303_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327303_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327303_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        39,873 reads @   4.5 µs/read;  13.23 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  39,873
# Reads with adapters:                        27 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        39,873 (100.0%)
#
# Total basepairs processed:     6,020,278 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      6,020,179 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 27 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	9	623.0	0	9
# 4	18	155.8	0	18
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327305_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327305_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327305_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327305_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        69,543 reads @   4.6 µs/read;  13.07 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  69,543
# Reads with adapters:                        49 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        69,543 (100.0%)
#
# Total basepairs processed:    10,439,292 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     10,439,105 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 49 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	12	1086.6	0	12
# 4	34	271.7	0	34
# 5	3	67.9	0	3
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327308_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327308_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327308_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327308_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        90,116 reads @   4.4 µs/read;  13.49 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  90,116
# Reads with adapters:                        78 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        90,116 (100.0%)
#
# Total basepairs processed:    13,605,312 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     13,605,022 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 78 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	25	1408.1	0	25
# 4	50	352.0	0	50
# 5	3	88.0	0	3
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327311_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327311_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327311_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327311_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        62,730 reads @   4.2 µs/read;  14.26 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  62,730
# Reads with adapters:                        78 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        62,730 (100.0%)
#
# Total basepairs processed:     9,470,391 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      9,470,104 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 78 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	26	980.2	0	26
# 4	51	245.0	0	51
# 5	1	61.3	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327313_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327313_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327313_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327313_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        61,432 reads @   4.4 µs/read;  13.51 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  61,432
# Reads with adapters:                        75 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        61,432 (100.0%)
#
# Total basepairs processed:     9,220,671 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      9,220,388 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 75 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	19	959.9	0	19
# 4	55	240.0	0	55
# 6	1	15.0	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327314_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327314_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327314_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327314_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        54,500 reads @   4.4 µs/read;  13.57 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  54,500
# Reads with adapters:                        45 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        54,500 (100.0%)
#
# Total basepairs processed:     8,216,138 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      8,215,973 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 45 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	15	851.6	0	15
# 4	30	212.9	0	30
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327316_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327316_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327316_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327316_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        77,716 reads @   4.3 µs/read;  13.84 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  77,716
# Reads with adapters:                       101 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        77,716 (100.0%)
#
# Total basepairs processed:    11,724,726 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,724,343 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 101 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	21	1214.3	0	21
# 4	80	303.6	0	80
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327317_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327317_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327317_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327317_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        56,804 reads @   4.5 µs/read;  13.41 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  56,804
# Reads with adapters:                        60 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        56,804 (100.0%)
#
# Total basepairs processed:     8,571,877 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      8,571,650 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 60 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	14	887.6	0	14
# 4	45	221.9	0	45
# 5	1	55.5	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327318_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327318_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327318_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327318_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        75,301 reads @   4.5 µs/read;  13.42 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  75,301
# Reads with adapters:                        80 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        75,301 (100.0%)
#
# Total basepairs processed:    11,369,216 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,368,898 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 80 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	14	1176.6	0	14
# 4	62	294.1	0	62
# 5	1	73.5	0	1
# 6	2	18.4	0	2
# 11	1	0.0	1	0 1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327322_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327322_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327322_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327322_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        69,741 reads @   4.4 µs/read;  13.59 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  69,741
# Reads with adapters:                       101 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        69,741 (100.0%)
#
# Total basepairs processed:    10,464,962 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     10,464,581 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 101 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	33	1089.7	0	33
# 4	61	272.4	0	61
# 5	5	68.1	0	5
# 6	1	17.0	0	1
# 7	1	4.3	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327323_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327323_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327323_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327323_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        68,793 reads @   4.3 µs/read;  14.03 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  68,793
# Reads with adapters:                        44 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        68,793 (100.0%)
#
# Total basepairs processed:    10,368,129 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     10,367,961 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 44 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	10	1074.9	0	10
# 4	32	268.7	0	32
# 5	2	67.2	0	2
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327325_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327325_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327325_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327325_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        32,700 reads @   4.5 µs/read;  13.28 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  32,700
# Reads with adapters:                        35 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        32,700 (100.0%)
#
# Total basepairs processed:     4,934,245 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      4,934,110 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 35 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	5	510.9	0	5
# 4	30	127.7	0	30
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327326_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327326_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327326_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327326_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        81,166 reads @   4.3 µs/read;  13.85 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  81,166
# Reads with adapters:                        59 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        81,166 (100.0%)
#
# Total basepairs processed:    12,255,190 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     12,254,972 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 59 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	20	1268.2	0	20
# 4	38	317.1	0	38
# 6	1	19.8	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327327_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327327_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327327_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327327_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        84,879 reads @   4.3 µs/read;  13.91 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  84,879
# Reads with adapters:                        79 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        84,879 (100.0%)
#
# Total basepairs processed:    12,814,733 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     12,814,445 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 79 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	29	1326.2	0	29
# 4	49	331.6	0	49
# 5	1	82.9	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327329_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327329_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327329_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327329_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        54,969 reads @   4.7 µs/read;  12.72 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  54,969
# Reads with adapters:                        34 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        54,969 (100.0%)
#
# Total basepairs processed:     8,287,105 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      8,286,979 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 34 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	11	858.9	0	11
# 4	22	214.7	0	22
# 5	1	53.7	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327332_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327332_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327332_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327332_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        66,003 reads @   4.4 µs/read;  13.67 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  66,003
# Reads with adapters:                        63 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        66,003 (100.0%)
#
# Total basepairs processed:     9,965,547 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      9,965,315 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 63 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	21	1031.3	0	21
# 4	41	257.8	0	41
# 5	1	64.5	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327335_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327335_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327335_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327335_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        62,732 reads @   4.5 µs/read;  13.28 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  62,732
# Reads with adapters:                        67 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        62,732 (100.0%)
#
# Total basepairs processed:     9,447,310 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      9,447,056 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 67 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	17	980.2	0	17
# 4	48	245.0	0	48
# 5	1	61.3	0	1
# 6	1	15.3	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327338_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327338_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327338_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327338_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        71,603 reads @   4.4 µs/read;  13.71 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  71,603
# Reads with adapters:                        74 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        71,603 (100.0%)
#
# Total basepairs processed:    10,745,232 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     10,744,939 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 74 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	9	1118.8	0	9
# 4	62	279.7	0	62
# 6	3	17.5	0	3
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327340_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327340_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327340_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327340_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        35,313 reads @   4.8 µs/read;  12.59 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  35,313
# Reads with adapters:                        30 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        35,313 (100.0%)
#
# Total basepairs processed:     5,299,801 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      5,299,690 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 30 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	10	551.8	0	10
# 4	19	137.9	0	19
# 5	1	34.5	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327343_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327343_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327343_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327343_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# ...
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327586_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327586_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        75,404 reads @   4.3 µs/read;  13.93 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  75,404
# Reads with adapters:                        80 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        75,404 (100.0%)
#
# Total basepairs processed:    11,276,994 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,276,691 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 80 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	18	1178.2	0	18
# 4	61	294.5	0	61
# 5	1	73.6	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327587_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327587_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327587_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327587_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        92,941 reads @   4.4 µs/read;  13.77 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  92,941
# Reads with adapters:                        90 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        92,941 (100.0%)
#
# Total basepairs processed:    13,977,211 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     13,976,872 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 90 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	23	1452.2	0	23
# 4	65	363.1	0	65
# 5	2	90.8	0	2
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327591_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327591_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327591_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327591_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        40,003 reads @   4.5 µs/read;  13.31 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  40,003
# Reads with adapters:                        66 (0.2%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        40,003 (100.0%)
#
# Total basepairs processed:     6,038,700 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      6,038,455 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 66 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	20	625.0	0	20
# 4	45	156.3	0	45
# 5	1	39.1	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327592_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327592_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327592_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327592_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        80,107 reads @   4.3 µs/read;  13.98 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  80,107
# Reads with adapters:                        70 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        80,107 (100.0%)
#
# Total basepairs processed:    12,029,643 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     12,029,384 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 70 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	22	1251.7	0	22
# 4	47	312.9	0	47
# 5	1	78.2	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327596_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327596_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327596_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327596_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        26,675 reads @   4.9 µs/read;  12.23 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  26,675
# Reads with adapters:                        43 (0.2%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        26,675 (100.0%)
#
# Total basepairs processed:     4,026,327 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      4,026,164 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 43 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	10	416.8	0	10
# 4	32	104.2	0	32
# 5	1	26.0	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327599_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327599_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327599_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327599_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        68,336 reads @   4.4 µs/read;  13.75 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  68,336
# Reads with adapters:                        71 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        68,336 (100.0%)
#
# Total basepairs processed:    10,317,121 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     10,316,850 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 71 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	16	1067.8	0	16
# 4	52	266.9	0	52
# 5	3	66.7	0	3
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327604_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327604_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327604_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327604_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        48,728 reads @   5.9 µs/read;  10.12 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  48,728
# Reads with adapters:                        38 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        48,728 (100.0%)
#
# Total basepairs processed:     7,357,221 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      7,357,075 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 38 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	6	761.4	0	6
# 4	32	190.3	0	32
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327605_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327605_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327605_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327605_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        76,774 reads @   4.2 µs/read;  14.15 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  76,774
# Reads with adapters:                        80 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        76,774 (100.0%)
#
# Total basepairs processed:    11,590,752 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,590,456 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 80 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	25	1199.6	0	25
# 4	54	299.9	0	54
# 5	1	75.0	0	1
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327615_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327615_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327615_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327615_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        93,805 reads @   5.1 µs/read;  11.80 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  93,805
# Reads with adapters:                       121 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        93,805 (100.0%)
#
# Total basepairs processed:    14,128,892 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     14,128,433 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 121 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	33	1465.7	0	33
# 4	83	366.4	0	83
# 5	2	91.6	0	2
# 6	3	22.9	0	3
#
# Command: cutadapt -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327620_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327620_01_L001_R1_001.fastq.gz
#
# This is cutadapt 5.1 with Python 3.10.14
# Command line parameters: -u 0 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -q 0,0 --quality-base 33 --cores 1 -o /tmp/qiime2/jovyan/processes/377-1763043391.11@jovyan/tmp/q2-OutPath-fo8glm1p/ERR5327620_01_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA /tmp/qiime2/jovyan/data/3638611d-1767-413b-9390-70ee3d78e4ff/data/ERR5327620_01_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        53,136 reads @   4.3 µs/read;  13.99 M reads/minute
#
# === Summary ===
#
# Total reads processed:                  53,136
# Reads with adapters:                        59 (0.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        53,136 (100.0%)
#
# Total basepairs processed:     8,022,095 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      8,021,877 bp (100.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 59 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20-22 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	18	830.2	0	18
# 4	41	207.6	0	41
# Saved SampleData[SequencesWithQuality] to: data/02/fungut_forward_reads_trimmed.qza

# %%
! qiime demux summarize \
  --i-data $data_dir/02/fungut_forward_reads_trimmed.qza \
  --o-visualization $data_dir/02/demux_summary_posttrimming.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: data/02/demux_summary_posttrimming.qzv

# %%
Visualization.load(f"{data_dir}/02/demux_summary_posttrimming.qzv")
# Out:
# <visualization: Visualization uuid: 0d3e386c-af85-41ad-b231-5e06605c2df4>

# %% [markdown]
# # 03 Denoising

# %% [markdown]
# ### --p-max-ee 4 — controls the maximum expected errors per read accepted by DADA2’s filtering. 4 is a relatively lenient filter; 1–2 is stricter and will remove more reads. Choose this based on the post-trim quality (look at the demux summary).

# %%
! qiime dada2 denoise-single \
   --i-demultiplexed-seqs $data_dir/02/fungut_forward_reads_trimmed.qza \
   --p-trim-left 0 \
   --p-trunc-len 0 \
   --p-min-fold-parent-over-abundance 4 \
   --p-max-ee 4 \
    --o-representative-sequences $data_dir/03/dada2_rep_seqs_1.qza \
    --o-table $data_dir/03/dada2_table_1.qza \
    --o-denoising-stats $data_dir/03/dada2_stats_1.qza
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved FeatureTable[Frequency] to: data/03/dada2_table_1.qza
# Saved FeatureData[Sequence] to: data/dada2_rep_seqs_1.qza
# Saved SampleData[DADA2Stats] to: data/03/dada2_stats_1.qza

# %%
# Convert denoising statistics to a QZV (shows per-sample read counts through DADA2 steps)
! qiime metadata tabulate \
    --m-input-file $data_dir/03/dada2_stats_1.qza \
    --o-visualization $data_dir/03/dada2_stats_1.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: data/03/dada2_stats_1.qzv

# %%
Visualization.load(f"{data_dir}/03/dada2_stats_1.qzv")
# Out:
# <visualization: Visualization uuid: 1585081b-afbe-47e1-89f3-e7b496265c12>

# %%
# Create interactive table of ASV representative sequences (inspect sequence lengths/content)
! qiime feature-table tabulate-seqs \
    --i-data $data_dir/03/dada2_rep_seqs_1.qza \
    --o-visualization $data_dir/03/dada2_rep_seqs_1.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: data/03/dada2_rep_seqs_1.qzv

# %%
Visualization.load(f"{data_dir}/03/dada2_rep_seqs_1.qzv")
# Out:
# <visualization: Visualization uuid: 6a817021-938f-4e7b-81c7-04c66d5a1548>

# %%
# Summarize feature table (check per-sample read depth, number of features, and overall counts)
! qiime feature-table summarize \
    --i-table $data_dir/03/dada2_table_1.qza \
    --m-sample-metadata-file $data_dir/fungut_metadata.tsv \
    --o-visualization $data_dir/03/dada2_table_1.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: data/03/dada2_table_1.qzv

# %%
Visualization.load(f"{data_dir}/03/dada2_table_1.qzv")
# Out:
# <visualization: Visualization uuid: 851382fd-9214-4ed4-994d-42f6b8dc9328>

# %% [markdown]
# Comparing denoised data with trunc. length 0 and 150:
# ITS sequences are more variable in length than 16S data. There is the risk of cutting the truncation length too short and loose valid ITS reads. Regarding that the the original data was good overall (everywhere over 30), it is better to keep all sequences. With this conclusion, it is decided to continue further steps with the data optained by run 1.

# %% [markdown]
# # 03-Checks to run now (after denoising) — pass/fail criteria to decide whether to proceed to taxonomy

# %% [markdown]
# Open the three QZVs (you already load them). For each, check the following items.
#
#
# B. From dada2_table_1.qzv (feature-table summary):
#
# Look at the sample frequency histogram. Decide a minimum read-depth cutoff for downstream analyses (alpha/beta). The cutoff should retain most samples but filter out failures. Document the cutoff.
#
# Look at number of features per sample: if many samples have very few features, they might be failures.
#
# Check whether any samples were dropped entirely (count=0).
#
# C. From dada2_rep_seqs_1.qzv (rep sequences):
#
# Inspect the length distribution of ASVs. ITS has variable lengths — confirm that distribution is biologically plausible and not dominated by very short sequences (primer dimers) or artifacts.
#
# If you find many very short sequences (<100 nt), consider filtering by minimum sequence length before taxonomic classification.
#
# D. Basic cross-checks:
#
# Ensure sample IDs in dada2_table_1.qzv match your metadata fungut_metadata.tsv. Use qiime metadata tabulate --m-input-file fungut_metadata.tsv (to generate metadata qzv) and visually compare IDs. Mismatched names cause downstream failures.
#
# Compute per-sample fraction unassigned after taxonomy (you’ll do this next) and flag samples with e.g., >50% unassigned.
#
# If these checks are acceptable (reasonable retention, acceptable chimera rate, plausible sequence length distribution, few low-depth samples), you can proceed to taxonomy.

# %% [markdown]
# # 04 Taxonomy Linus (done on Euler, imported qza file)

# %%
! qiime metadata tabulate \
    --m-input-file $data_dir/04/taxjoblinus.qza \
    --o-visualization $data_dir/04/taxonomylinus.qzv

# %%
Visualization.load(f"{data_dir}/04/taxonomylinus.qzv")

# %%
! qiime taxa barplot \
    --i-table $data_dir/03/dada2_table_1.qza \
    --i-taxonomy $data_dir/04/taxjoblinus.qza \
    --m-metadata-file $data_dir/fungut_metadata.tsv \
    --o-visualization $data_dir/04/taxa-bar-plots_linus.qzv

# %%
Visualization.load(f"{data_dir}/04/taxa-bar-plots_linus.qzv")

# %% [markdown]
# # 05 Filtering

# %% [markdown]
# Wir müssen alle samples rausfiltern die in der Taxonomy k_unclassified, nur k_fungi oder etwas anderes als k_fungi haben.

# %%
! qiime feature-table summarize \
  --i-table $data_dir/03/dada2_table_1.qza \
  --m-sample-metadata-file $data_dir/fungut_metadata.tsv \
  --o-visualization $data_dir/05/dada2_table_1_metadata.qzv
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saved Visualization to: data/05/dada2_table_1_metadata.qzv

# %%
Visualization.load(f"{data_dir}/05/dada2_table_1_metadata.qzv")
# Out:
# <visualization: Visualization uuid: 9fec8d9f-de05-46b6-8fd7-15e7476612af>

# %% [markdown]
# von livia pbernehmen und dann anpassen mit ordnersystem

# %% [markdown]
# Filtering per tsv:
#     - Filter out unwanted samples in tsv file
#     - Group metadata (age and BMI)
#     - Change "Not provided" to Nan

# %% [markdown]
# # 06 Preparing for further analysis

# %% [markdown]
# ## 06.1 Selecting sequencing depth

# %%
#30000
! qiime diversity alpha-rarefaction \
    --i-table $data_dir/dada2_table_1.qza \
    --p-max-depth 30000 \
    --m-metadata-file $data_dir/fungut_metadata.tsv \
    --o-visualization $data_dir/06/fungut_alpha_rarefaction_30000.qzv

# %%
#50000
! qiime diversity alpha-rarefaction \
    --i-table $data_dir/dada2_table_1.qza \
    --p-max-depth 50000 \
    --m-metadata-file $data_dir/fungut_metadata.tsv \
    --o-visualization $data_dir/06/fungut_alpha_rarefaction_50000.qzv

# %%
Visualization.load(f"{data_dir}/06/fungut_alpha_rarefaction_30000.qzv")

# %%
Visualization.load(f"{data_dir}/06/fungut_alpha_rarefaction_50000.qzv")

# %% [markdown]
# ##### Sequencing depths to test (how many samples do we loose?):
#     1. 17500
#     2. 20000
#     3. 22500
#
# Results:
# 17500: no samples lost (150)
# 20000: 1 sample lost (149)
# 22500: 3 samples lost (147)
#
# -> Lets go with 20000. This way we have a good plateau for all curves and lose only 1 sample.
# -> We don't have any extremly low-depth samples that might need filtering (yay!)

# %%
Test = 17500
# !qiime feature-table filter-samples \
  --i-table $data_dir/dada2_table_1.qza \
  --p-min-frequency 17500 \
  --o-filtered-table $data_dir/06/table_minfreq_17500.qza

# !qiime feature-table summarize \
  --i-table $data_dir/06/table_minfreq_17500.qza \
  --m-sample-metadata-file $data_dir/fungut_metadata.tsv \
  --o-visualization $data_dir/06/table_minfreq_17500_summary.qzv

# %%
# Depth 20000
# !qiime feature-table filter-samples \
  --i-table $data_dir/dada2_table_1.qza \
  --p-min-frequency 20000 \
  --o-filtered-table $data_dir/06/table_minfreq_20000.qza

# !qiime feature-table summarize \
  --i-table $data_dir/06/table_minfreq_20000.qza \
  --m-sample-metadata-file $data_dir/fungut_metadata.tsv \
  --o-visualization $data_dir/06/table_minfreq_20000_summary.qzv

# %%
# Depth 22500
# !qiime feature-table filter-samples \
  --i-table $data_dir/dada2_table_1.qza \
  --p-min-frequency 22500 \
  --o-filtered-table $data_dir/06/table_minfreq_22500.qza

# !qiime feature-table summarize \
  --i-table $data_dir/06/table_minfreq_22500.qza \
  --m-sample-metadata-file $data_dir/fungut_metadata.tsv \
  --o-visualization $data_dir/06/table_minfreq_22500_summary.qzv

# %%
Visualization.load(f"{data_dir}/06/table_minfreq_17500_summary.qzv")

# %%
Visualization.load(f"{data_dir}/06/table_minfreq_20000_summary.qzv")

# %%
Visualization.load(f"{data_dir}/06/table_minfreq_22500_summary.qzv")

# %% [markdown]
# ## 06.02 Final check before Bootrstrapping

# %%
# !qiime diversity alpha-rarefaction \
  --i-table $data_dir/dada2_table_1.qza \
  --p-max-depth 23000 \
  --p-iterations 50 \
  --m-metadata-file $data_dir/fungut_metadata.tsv \
  --o-visualization $data_dir/06/alpha_rarefaction_sanitycheck.qzv

# %%
Visualization.load(f"{data_dir}/06/alpha_rarefaction_sanitycheck.qzv")

# %% [markdown]
# # 07 Alpha diversity

# %% [markdown]
# ### 07.01 Kmerizing our ASVs

# %%
#Here I probably have to use the feature table after filtering
! qiime kmerizer core-metrics \
  --i-table $data_dir/03/dada2_table_1.qza \
  --i-sequences $data_dir/03/dada2_rep_seqs_1.qza \
  --m-metadata-file $data_dir/fungut_metadata.tsv \
  --p-sampling-depth 20000 \
  --p-kmer-size 16 \
  --output-dir $data_dir/fungut_kmerizer_output

# %%
# !qiime tools peek $data_dir/fungut_forward_reads.qza
# Out:
# UUID:        3638611d-1767-413b-9390-70ee3d78e4ff
# Type:        SampleData[SequencesWithQuality]
# Data format: SingleLanePerSampleSingleEndFastqDirFmt

# %%
# !qiime boots kmer-diversity \
  --i-table $data_dir/03/dada2_table_1.qza \
  --i-sequences $data_dir/fungut_forward_reads.qza \
  --m-metadata-file $data_dir/fungut_metadata.tsv \
  --p-sampling-depth 20000 \
  --p-n 10 \
  --p-replacement \
  --p-kmer-size 16 \
  --p-alpha-average-method median \
  --p-beta-average-method medoid \
  --p-color-by "country_sample" \
  --output-dir boots-kmer-diversity
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Usage: qiime boots kmer-diversity [OPTIONS]
#
#   Given a single feature table as input, this action resamples the feature
#   table `n` times to a total frequency of `sampling depth` per sample. It then
#   splits all input sequences into kmers, and computes common alpha and beta
#   diversity on each resulting kmer table. The resulting artifacts are then
#   averaged using the method specified by `alpha_average_method` and
#   `beta_average_method` parameters. The resulting average alpha and beta
#   diversity artifacts are returned, along with a scatter plot integrated all
#   alpha diversity metrics and the PCoA axes for all beta diversity metrics.
#
# Inputs:
#   --i-table ARTIFACT FeatureTable[Frequency | RelativeFrequency |
#     PresenceAbsence]      The input feature table.                  [required]
#   --i-sequences ARTIFACT FeatureData[Sequence | RNASequence |
#     ProteinSequence]      Input sequences for kmerization.          [required]
# Parameters:
#   --p-sampling-depth INTEGER
#     Range(1, None)        The total number of observations that each sample
#                           in `table` should be resampled to. Samples where the
#                           total number of observations in `table` is less than
#                           `sampling-depth` will be not be included in the
#                           output tables.                            [required]
#   --m-metadata-file METADATA...
#     (multiple arguments   The sample metadata used in generating Emperor
#      will be merged)      plots.                                    [required]
#   --p-n INTEGER           The number of resampled tables that should be
#     Range(1, None)        generated.                                [required]
#   --p-replacement / --p-no-replacement
#                           Resample `table` with replacement (i.e., bootstrap)
#                           or without replacement (i.e., rarefaction).
#                                                                     [required]
#   --p-kmer-size INTEGER   Length of kmers to generate.           [default: 16]
#   --p-tfidf / --p-no-tfidf
#                           If True, kmers will be scored using TF-IDF and
#                           output frequencies will be weighted by scores. If
#                           False, kmers are counted without TF-IDF scores.
#                                                               [default: False]
#   --p-max-df VALUE Float % Range(0, 1, inclusive_end=True) | Int
#                           Ignore kmers that have a frequency strictly higher
#                           than the given threshold. If float, the parameter
#                           represents a proportion of sequences, if an integer
#                           it represents an absolute count.      [default: 1.0]
#   --p-min-df VALUE Float % Range(0, 1) | Int
#                           Ignore kmers that have a frequency strictly lower
#                           than the given threshold. If float, the parameter
#                           represents a proportion of sequences, if an integer
#                           it represents an absolute count.        [default: 1]
#   --p-max-features INTEGER
#                           If not None, build a vocabulary that only considers
#                           the top max-features ordered by frequency (or TF-IDF
#                           score).                                   [optional]
#   --p-alpha-average-method TEXT Choices('mean', 'median')
#                           Method to use for averaging alpha diversity.
#                                                            [default: 'median']
#   --p-beta-average-method TEXT Choices('non-metric-mean',
#     'non-metric-median', 'medoid')
#                           Method to use for averaging beta diversity.
#                                                 [default: 'non-metric-median']
#   --p-pc-dimensions INTEGER
#                           Number of principal coordinate dimensions to
#                           present in the 2D scatterplot.          [default: 3]
#   --p-color-by TEXT       Categorical measure from the input Metadata that
#                           should be used for color-coding the 2D scatterplot.
#                                                                     [optional]
#   --p-norm TEXT Choices('None', 'l1', 'l2')
#                           Normalization procedure applied to TF-IDF scores.
#                           Ignored if tfidf=False. l2: Sum of squares of vector
#                           elements is 1. l1: Sum of absolute values of vector
#                           elements is 1.                     [default: 'None']
#   --p-alpha-metrics TEXT... Choices('ace', 'berger_parker_d',
#     'brillouin_d', 'chao1', 'chao1_ci', 'dominance', 'doubles', 'enspie',
#     'esty_ci', 'fisher_alpha', 'gini_index', 'goods_coverage', 'heip_e',
#     'kempton_taylor_q', 'lladser_pe', 'margalef', 'mcintosh_d', 'mcintosh_e',
#     'menhinick', 'michaelis_menten_fit', 'observed_features', 'osd',
#     'pielou_e', 'robbins', 'shannon', 'simpson', 'simpson_e', 'singles',
#     'strong')
#                        [default: ['pielou_e', 'observed_features', 'shannon']]
#   --p-beta-metrics TEXT... Choices('aitchison', 'braycurtis', 'canberra',
#     'canberra_adkins', 'chebyshev', 'cityblock', 'correlation', 'cosine',
#     'dice', 'euclidean', 'hamming', 'jaccard', 'jensenshannon', 'matching',
#     'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean',
#     'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule')
#                                           [default: ['braycurtis', 'jaccard']]
# Outputs:
#   --o-resampled-tables ARTIFACTS... Collection[FeatureTable[Frequency]]
#                           The `n` resampled tables.                 [required]
#   --o-kmer-tables ARTIFACTS... Collection[FeatureTable[Frequency]]
#                           The `n` kmer tables.                      [required]
#   --o-alpha-diversities ARTIFACTS... Collection[SampleData[AlphaDiversity]]
#                           Average alpha diversity vector for each metric.
#                                                                     [required]
#   --o-distance-matrices ARTIFACTS... Collection[DistanceMatrix]
#                           Average beta diversity distance matrix for each
#                           metric.                                   [required]
#   --o-pcoas ARTIFACTS... Collection[PCoAResults]
#                           PCoA matrix for each beta diversity metric.
#                                                                     [required]
#   --o-scatter-plot VISUALIZATION
#                           2D scatter plot including alpha diversity and pcoa
#                           results for all selected metrics.         [required]
# Miscellaneous:
#   --output-dir PATH       Output unspecified results to a directory
#   --verbose / --quiet     Display verbose output to stdout and/or stderr
#                           during execution of this action. Or silence output
#                           if execution is successful (silence is golden).
#   --recycle-pool TEXT     Use a cache pool for pipeline resumption. QIIME 2
#                           will cache your results in this pool for reuse by
#                           future invocations. These pool are retained until
#                           deleted by the user. If not provided, QIIME 2 will
#                           create a pool which is automatically reused by
#                           invocations of the same action and removed if the
#                           action is successful. Note: these pools are local to
#                           the cache you are using.
#   --no-recycle            Do not recycle results from a previous failed
#                           pipeline run or save the results from this run for
#                           future recycling.
#   --parallel              Execute your action in parallel. This flag will use
#                           your default parallel config.
#   --parallel-config FILE  Execute your action in parallel using a config at
#                           the indicated path.
#   --example-data PATH     Write example data and exit.
#   --citations             Show citations and exit.
#   --use-cache DIRECTORY   Specify the cache to be used for the intermediate
#                           work of this action. If not provided, the default
#                           cache under $TMP/qiime2/<uname> will be used.
#                           IMPORTANT FOR HPC USERS: If you are on an HPC system
#                           and are using parallel execution it is important to
#                           set this to a location that is globally accessible
#                           to all nodes in the cluster.
#   --help                  Show this message and exit.
#
# Examples:
#   # ### example: Bootstrapped kmer diversity
#   qiime boots kmer-diversity \
#     --i-table table.qza \
#     --i-sequences sequences.qza \
#     --m-metadata-file metadata.tsv \
#     --p-sampling-depth 20 \
#     --p-n 10 \
#     --p-kmer-size 5 \
#     --p-replacement \
#     --p-alpha-average-method median \
#     --p-beta-average-method medoid \
#     --o-resampled-tables bootstrap-tables/ \
#     --o-kmer-tables kmer-tables/ \
#     --o-alpha-diversities bootstrap-alpha-diversities/ \
#     --o-distance-matrices bootstrap-distance-matrices/ \
#     --o-pcoas bootstrap-pcoas/ \
#     --o-scatter-plot scatter-plot.qzv
#
#
#                     There was a problem with the command:
#  (1/1) Invalid value for '--i-sequences': Expected an artifact of at least
#   type FeatureData[Sequence | RNASequence | ProteinSequence]. An artifact of
#   type SampleData[SequencesWithQuality] was provided.

# %% [markdown]
# ### Questions regarding boots kmer diversity
# - when to use mean when median?
# - replace or not replace?
# - Currently we use the nontrimmed sequences, how can I use the trimmed ones (filetype supposedly not supported)

# %%
# !qiime boots kmer-diversity ?
# Out:
# Usage: qiime boots kmer-diversity [OPTIONS]
#
#   Given a single feature table as input, this action resamples the feature
#   table `n` times to a total frequency of `sampling depth` per sample. It then
#   splits all input sequences into kmers, and computes common alpha and beta
#   diversity on each resulting kmer table. The resulting artifacts are then
#   averaged using the method specified by `alpha_average_method` and
#   `beta_average_method` parameters. The resulting average alpha and beta
#   diversity artifacts are returned, along with a scatter plot integrated all
#   alpha diversity metrics and the PCoA axes for all beta diversity metrics.
#
# Inputs:
#   --i-table ARTIFACT FeatureTable[Frequency | RelativeFrequency |
#     PresenceAbsence]      The input feature table.                  [required]
#   --i-sequences ARTIFACT FeatureData[Sequence | RNASequence |
#     ProteinSequence]      Input sequences for kmerization.          [required]
# Parameters:
#   --p-sampling-depth INTEGER
#     Range(1, None)        The total number of observations that each sample
#                           in `table` should be resampled to. Samples where the
#                           total number of observations in `table` is less than
#                           `sampling-depth` will be not be included in the
#                           output tables.                            [required]
#   --m-metadata-file METADATA...
#     (multiple arguments   The sample metadata used in generating Emperor
#      will be merged)      plots.                                    [required]
#   --p-n INTEGER           The number of resampled tables that should be
#     Range(1, None)        generated.                                [required]
#   --p-replacement / --p-no-replacement
#                           Resample `table` with replacement (i.e., bootstrap)
#                           or without replacement (i.e., rarefaction).
#                                                                     [required]
#   --p-kmer-size INTEGER   Length of kmers to generate.           [default: 16]
#   --p-tfidf / --p-no-tfidf
#                           If True, kmers will be scored using TF-IDF and
#                           output frequencies will be weighted by scores. If
#                           False, kmers are counted without TF-IDF scores.
#                                                               [default: False]
#   --p-max-df VALUE Float % Range(0, 1, inclusive_end=True) | Int
#                           Ignore kmers that have a frequency strictly higher
#                           than the given threshold. If float, the parameter
#                           represents a proportion of sequences, if an integer
#                           it represents an absolute count.      [default: 1.0]
#   --p-min-df VALUE Float % Range(0, 1) | Int
#                           Ignore kmers that have a frequency strictly lower
#                           than the given threshold. If float, the parameter
#                           represents a proportion of sequences, if an integer
#                           it represents an absolute count.        [default: 1]
#   --p-max-features INTEGER
#                           If not None, build a vocabulary that only considers
#                           the top max-features ordered by frequency (or TF-IDF
#                           score).                                   [optional]
#   --p-alpha-average-method TEXT Choices('mean', 'median')
#                           Method to use for averaging alpha diversity.
#                                                            [default: 'median']
#   --p-beta-average-method TEXT Choices('non-metric-mean',
#     'non-metric-median', 'medoid')
#                           Method to use for averaging beta diversity.
#                                                 [default: 'non-metric-median']
#   --p-pc-dimensions INTEGER
#                           Number of principal coordinate dimensions to
#                           present in the 2D scatterplot.          [default: 3]
#   --p-color-by TEXT       Categorical measure from the input Metadata that
#                           should be used for color-coding the 2D scatterplot.
#                                                                     [optional]
#   --p-norm TEXT Choices('None', 'l1', 'l2')
#                           Normalization procedure applied to TF-IDF scores.
#                           Ignored if tfidf=False. l2: Sum of squares of vector
#                           elements is 1. l1: Sum of absolute values of vector
#                           elements is 1.                     [default: 'None']
#   --p-alpha-metrics TEXT... Choices('ace', 'berger_parker_d',
#     'brillouin_d', 'chao1', 'chao1_ci', 'dominance', 'doubles', 'enspie',
#     'esty_ci', 'fisher_alpha', 'gini_index', 'goods_coverage', 'heip_e',
#     'kempton_taylor_q', 'lladser_pe', 'margalef', 'mcintosh_d', 'mcintosh_e',
#     'menhinick', 'michaelis_menten_fit', 'observed_features', 'osd',
#     'pielou_e', 'robbins', 'shannon', 'simpson', 'simpson_e', 'singles',
#     'strong')
#                        [default: ['pielou_e', 'observed_features', 'shannon']]
#   --p-beta-metrics TEXT... Choices('aitchison', 'braycurtis', 'canberra',
#     'canberra_adkins', 'chebyshev', 'cityblock', 'correlation', 'cosine',
#     'dice', 'euclidean', 'hamming', 'jaccard', 'jensenshannon', 'matching',
#     'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean',
#     'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule')
#                                           [default: ['braycurtis', 'jaccard']]
# Outputs:
#   --o-resampled-tables ARTIFACTS... Collection[FeatureTable[Frequency]]
#                           The `n` resampled tables.                 [required]
#   --o-kmer-tables ARTIFACTS... Collection[FeatureTable[Frequency]]
#                           The `n` kmer tables.                      [required]
#   --o-alpha-diversities ARTIFACTS... Collection[SampleData[AlphaDiversity]]
#                           Average alpha diversity vector for each metric.
#                                                                     [required]
#   --o-distance-matrices ARTIFACTS... Collection[DistanceMatrix]
#                           Average beta diversity distance matrix for each
#                           metric.                                   [required]
#   --o-pcoas ARTIFACTS... Collection[PCoAResults]
#                           PCoA matrix for each beta diversity metric.
#                                                                     [required]
#   --o-scatter-plot VISUALIZATION
#                           2D scatter plot including alpha diversity and pcoa
#                           results for all selected metrics.         [required]
# Miscellaneous:
#   --output-dir PATH       Output unspecified results to a directory
#   --verbose / --quiet     Display verbose output to stdout and/or stderr
#                           during execution of this action. Or silence output
#                           if execution is successful (silence is golden).
#   --recycle-pool TEXT     Use a cache pool for pipeline resumption. QIIME 2
#                           will cache your results in this pool for reuse by
#                           future invocations. These pool are retained until
#                           deleted by the user. If not provided, QIIME 2 will
#                           create a pool which is automatically reused by
#                           invocations of the same action and removed if the
#                           action is successful. Note: these pools are local to
#                           the cache you are using.
#   --no-recycle            Do not recycle results from a previous failed
#                           pipeline run or save the results from this run for
#                           future recycling.
#   --parallel              Execute your action in parallel. This flag will use
#                           your default parallel config.
#   --parallel-config FILE  Execute your action in parallel using a config at
#                           the indicated path.
#   --example-data PATH     Write example data and exit.
#   --citations             Show citations and exit.
#   --use-cache DIRECTORY   Specify the cache to be used for the intermediate
#                           work of this action. If not provided, the default
#                           cache under $TMP/qiime2/<uname> will be used.
#                           IMPORTANT FOR HPC USERS: If you are on an HPC system
#                           and are using parallel execution it is important to
#                           set this to a location that is globally accessible
#                           to all nodes in the cluster.
#   --help                  Show this message and exit.
#
# Examples:
#   # ### example: Bootstrapped kmer diversity
#   qiime boots kmer-diversity \
#     --i-table table.qza \
#     --i-sequences sequences.qza \
#     --m-metadata-file metadata.tsv \
#     --p-sampling-depth 20 \
#     --p-n 10 \
#     --p-kmer-size 5 \
#     --p-replacement \
#     --p-alpha-average-method median \
#     --p-beta-average-method medoid \
#     --o-resampled-tables bootstrap-tables/ \
#     --o-kmer-tables kmer-tables/ \
#     --o-alpha-diversities bootstrap-alpha-diversities/ \
#     --o-distance-matrices bootstrap-distance-matrices/ \
#     --o-pcoas bootstrap-pcoas/ \
#     --o-scatter-plot scatter-plot.qzv
#
#
#                   There were some problems with the command:
#  (1/13) Missing option '--i-table'.
#  (2/13) Missing option '--i-sequences'.
#  (3/13) Missing option '--p-sampling-depth'.
#  (4/13) Missing option '--m-metadata-file'.
#  (5/13) Missing option '--p-n'.
#  (6/13) Missing option '--p-replacement'.
#  (7/13) Missing option '--o-resampled-tables'. ("--output-dir" may also be
#   used)
#  (8/13) Missing option '--o-kmer-tables'. ("--output-dir" may also be used)
#  (9/13) Missing option '--o-alpha-diversities'. ("--output-dir" may also be
#   used)
#  (10/13) Missing option '--o-distance-matrices'. ("--output-dir" may also be
#   used)
#  (11/13) Missing option '--o-pcoas'. ("--output-dir" may also be used)
#  (12/13) Missing option '--o-scatter-plot'. ("--output-dir" may also be used)
#  (13/13) Got unexpected extra argument (?)

# %% [markdown]
# ## ?? Alpha diversity Analysis old

# %%
! qiime diversity core-metrics \
  --i-table $data_dir/dada2_table_1.qza  \
  --m-metadata-file $data_dir/fungut_metadata.tsv \
  --p-sampling-depth 17500 \
  --output-dir $data_dir/fungut_coremetrics

# %%
# Sind das jetzt die richtigen Sequenzen? Sind nicht getrimmt aber mit den anderen gehts irgendwie nicht (siehe Datentypen oben)

! qiime kmerizer core-metrics \
  --i-table $data_dir/dada2_table_1.qza \
  --i-sequences $data_dir/dada2_rep_seqs_1.qza \
  --m-metadata-file $data_dir/fungut_metadata.tsv \
  --p-sampling-depth 17500 \
  --p-kmer-size 16 \
  --output-dir $data_dir/fungut_kmerizer_output

# %% [markdown]
# ### 06.2.1 Alpha diversity: Statistical testing

# %%
! qiime diversity alpha-group-significance \
  --i-alpha-diversity $data_dir/fungut_coremetrics/shannon_vector.qza \
  --m-metadata-file $data_dir/fungut_metadata.tsv \
  --o-visualization $data_dir/fungut_coremetrics/shannon-group-significance.qzv

# %%
Visualization.load(f"{data_dir}/fungut_coremetrics/shannon-group-significance.qzv")

# %%
! qiime diversity alpha-correlation \
  --i-alpha-diversity $data_dir/fungut_coremetrics/shannon_vector.qza \
  --m-metadata-file $data_dir/fungut_metadata.tsv \
  --o-visualization $data_dir/fungut_coremetrics/shannon-group-significance-numeric.qzv

# %%
Visualization.load(f"{data_dir}/fungut_coremetrics/shannon-group-significance-numeric.qzv")

# %%
# !qiime boots kmer-diversity ?
